# %%
import pandas as pd

# %%
data_file = "/Users/francis/Documents/Tableau_HW/JC-201901-citibike-tripdata.csv"

# %%
data_file_pd = pd.read_csv(data_file)
data_file_pd.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           201   09:09.7  12:30.9              3183     Exchange Place
# 1           505   18:00.1  26:25.9              3183     Exchange Place
# 2           756   36:33.3  49:10.3              3183     Exchange Place
# 3          1575   43:38.6  09:54.5              3183     Exchange Place
# 4          1566   43:39.6  09:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3638
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3638
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
data_file_pd.rename(columns = {'Trip Duration': 'tripduration', 'Start Time': 'starttime', 
                      'Stop Time': 'stoptime', 'Gender':'gender', "User Type": "usertype",
                      'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                      'Start Station Name': 'start station name', 'Start Station Latitude': 'start station latitude',
                      'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id', 
                      'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude',
                      'End Station Longitude': 'end station longitude'}, inplace = True)
data_file_pd.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           201   09:09.7  12:30.9              3183     Exchange Place
# 1           505   18:00.1  26:25.9              3183     Exchange Place
# 2           756   36:33.3  49:10.3              3183     Exchange Place
# 3          1575   43:38.6  09:54.5              3183     Exchange Place
# 4          1566   43:39.6  09:46.5              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3214
# 1               40.716247               -74.033459            3638
# 2               40.716247               -74.033459            3192
# 3               40.716247               -74.033459            3638
# 4               40.716247               -74.033459            3638
#
#      end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
data_file2 = "/Users/francis/Documents/Tableau_HW/JC-201902-citibike-tripdata.csv"

# %%
data_file2_pd = pd.read_csv(data_file2)
data_file2_pd.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           142   35:02.1  37:24.1              3183     Exchange Place
# 1           223   00:46.9  04:30.5              3183     Exchange Place
# 2           106   08:01.3  09:47.4              3183     Exchange Place
# 3           370   09:31.2  15:41.7              3183     Exchange Place
# 4           315   19:53.2  25:09.1              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3639
# 1               40.716247               -74.033459            3681
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3211
# 4               40.716247               -74.033459            3273
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
data_file2_pd.rename(columns = {'Trip Duration': 'tripduration', 'Start Time': 'starttime', 
                      'Stop Time': 'stoptime', 'Gender':'gender', "User Type": "usertype",
                      'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                      'Start Station Name': 'start station name', 'Start Station Latitude': 'start station latitude',
                      'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id', 
                      'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude',
                      'End Station Longitude': 'end station longitude'}, inplace = True)
data_file2_pd.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           142   35:02.1  37:24.1              3183     Exchange Place
# 1           223   00:46.9  04:30.5              3183     Exchange Place
# 2           106   08:01.3  09:47.4              3183     Exchange Place
# 3           370   09:31.2  15:41.7              3183     Exchange Place
# 4           315   19:53.2  25:09.1              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3639
# 1               40.716247               -74.033459            3681
# 2               40.716247               -74.033459            3184
# 3               40.716247               -74.033459            3211
# 4               40.716247               -74.033459            3273
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
data_file3 = "/Users/francis/Documents/Tableau_HW/JC-201903-citibike-tripdata.csv"

# %%
data_file3_pd = pd.read_csv(data_file3)
data_file3_pd.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           306   47:08.2  52:14.7              3183     Exchange Place
# 1           123   30:53.0  32:56.8              3183     Exchange Place
# 2           328   18:30.4  23:59.1              3183     Exchange Place
# 3            95   04:47.2  06:22.8              3183     Exchange Place
# 4           169   51:29.4  54:19.2              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3267
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3213
# 3               40.716247               -74.033459            3184
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
data_file3_pd.rename(columns = {'Trip Duration': 'tripduration', 'Start Time': 'starttime', 
                      'Stop Time': 'stoptime', 'Gender':'gender', "User Type": "usertype",
                      'Bike ID': 'bikeid', 'Birth Year': 'birth year', 'Start Station ID': 'start station id',
                      'Start Station Name': 'start station name', 'Start Station Latitude': 'start station latitude',
                      'Start Station Longitude': 'start station longitude', 'End Station ID': 'end station id', 
                      'End Station Name': 'end station name', 'End Station Latitude': 'end station latitude',
                      'End Station Longitude': 'end station longitude'}, inplace = True)
data_file3_pd.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           306   47:08.2  52:14.7              3183     Exchange Place
# 1           123   30:53.0  32:56.8              3183     Exchange Place
# 2           328   18:30.4  23:59.1              3183     Exchange Place
# 3            95   04:47.2  06:22.8              3183     Exchange Place
# 4           169   51:29.4  54:19.2              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3267
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3213
# 3               40.716247               -74.033459            3184
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
citibike_1Qtr2019 = pd.concat([data_file_pd, data_file_pd, data_file_pd])
citibike_1Qtr2019
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               201   09:09.7  12:30.9              3183     Exchange Place
# 1               505   18:00.1  26:25.9              3183     Exchange Place
# 2               756   36:33.3  49:10.3              3183     Exchange Place
# 3              1575   43:38.6  09:54.5              3183     Exchange Place
# 4              1566   43:39.6  09:46.5              3183     Exchange Place
# ...             ...       ...      ...               ...                ...
# 19671           853   40:17.3  54:30.9              3694     Jackson Square
# 19672           936   36:20.6  51:57.1              3694     Jackson Square
# 19673           653   14:08.5  25:01.6              3694     Jackson Square
# 19674           960   15:26.6  31:26.7              3694     Jackson Square
# 19675          1109   30:03.6  48:33.3              3694     Jackson Square
#
# ...

# %%
citibike_1Qtr2019.to_csv('citibike_1Qtr2019.csv', sep = ',')
